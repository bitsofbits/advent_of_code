# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
scores = np.array(
    [
        1,
        5,
        7,
        18,
        33,
        82,
        160,
        366,
        727,
        1588,
        3182,
        6750,
        13573,
        28261,
        56892,
        117020,
        235560,
        480563,
        966805,
        1961318,
    ]
)

# %%
n = 8
i = np.arange(len(scores))
plt.plot(scores[n:] - 1.15 * 2**n * scores[:-n])
